# %% [markdown]
# Matching data

# %%
import pandas as pd
import numpy as np


df1 = pd.read_excel('BDD_NAO.xlsx', sheet_name='Echantillon NAO 2023')
df2 = pd.read_excel('BDD_NAO.xlsx', sheet_name='Saisie')

# %%
df1["Entreprise"].head(20)
# Out:
# 0            GRANDS MOULINS DE PARIS (NAO 2022-2023)
# 1                                    ROYAL CANIN SAS
# 2                                      BOIRON FRERES
# 3                          UNITED PETFOOD FRANCE-UPF
# 4                                      LDC AQUITAINE
# 5                                        SAS GUILLET
# 6                               COCA COLA PRODUCTION
# 7     SOC COOPERATIVE AGRICOLE FOIE GRAS DE CHALOSSE
# 8                            BOULANGERIE DE L'EUROPE
# 9               VANDEMOORTELE BAKERY PRODUCTS FRANCE
# 10                               FLORETTE FRANCE GMS
# 11                                     OPTIMUM S.A.S
# 12                                    GAUTIER FRANCE
# 13                          HIPPO GESTION ET CIE SNC
# 14                                 POMONA EPISAVEURS
# 15                                    VORWERK FRANCE
# 16                                       PMG ARDECHE
# 17                                 GIE FILHET ALLARD
# 18                              VANDEMOORTELE EUROPE
# 19                                  TANNERIES DU PUY
# Name: Entreprise, dtype: object

# %%
df3 = pd.merge(df1, df2, how='right', left_on=['Entreprise'], right_on=["Nom de l'entreprise "])
df3
# Out:
#                                          UrlLegifrance  \
# 0    https://www.legifrance.gouv.fr/acco/id/ACCOTEX...
# 1    https://www.legifrance.gouv.fr/acco/id/ACCOTEX...
# 2    https://www.legifrance.gouv.fr/acco/id/ACCOTEX...
# 3    https://www.legifrance.gouv.fr/acco/id/ACCOTEX...
# 4    https://www.legifrance.gouv.fr/acco/id/ACCOTEX...
# ..                                                 ...
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
# 205                                                NaN
# 206                                                NaN
#
#                                        Entreprise  \
# 0                                    LILLY FRANCE
# 1                                 RAMERY PROPRETE
# 2    BANQUE POPULAIRE AQUITAINE CENTRE ATLANTIQUE
# 3             GLENAT ENTREPRISES ET DEVELOPPEMENT
# 4                                 VALLOUREC TUBES
# ..                                            ...
# 202                                           NaN
# 203                                           NaN
# 204                                           NaN
# 205                                           NaN
# 206                                           NaN
#
#                                       recherche v       Siret_x  \
# 0                                    LILLY FRANCE  6.098492e+13
# 1                                 RAMERY PROPRETE  4.847630e+13
# 2    BANQUE POPULAIRE AQUITAINE CENTRE ATLANTIQUE  7.555016e+13
# 3             GLENAT ENTREPRISES ET DEVELOPPEMENT  3.477463e+13
# 4                                 VALLOUREC TUBES  4.113735e+13
# ..                                            ...           ...
# 202                                           NaN           NaN
# 203                                           NaN           NaN
# 204                                           NaN           NaN
# 205                                           NaN           NaN
# 206                                           NaN           NaN
#
#     Secteur SECAFI                         Secteur Naf732  \
# 0               ND    Activités des sièges sociaux  7010Z
# 1               ND    Activités des sièges sociaux  7010Z
# 2               ND    Activités des sièges sociaux  7010Z
# 3               ND  Activités des sociétés holding  6420Z
# 4               ND    Activités des sièges sociaux  7010Z
# ..             ...                             ...    ...
# 202            NaN                             NaN    NaN
# 203            NaN                             NaN    NaN
# 204            NaN                             NaN    NaN
# 205            NaN                             NaN    NaN
# 206            NaN                             NaN    NaN
#
#               Date Texte Tranche Effectif(Base siren)  Nature  ...  \
# 0    2022-11-23 00:00:00       1 000 à 1 999 salariés  ACCORD  ...
# 1    2022-11-04 00:00:00           100 à 199 salariés  ACCORD  ...
# 2    2022-09-29 00:00:00       2 000 à 4 999 salariés  ACCORD  ...
# 3    2022-12-12 00:00:00             20 à 49 salariés  ACCORD  ...
# 4    2022-11-22 00:00:00           200 à 249 salariés  ACCORD  ...
# ..                   ...                          ...     ...  ...
# 202                  NaN                          NaN     NaN  ...
# 203                  NaN                          NaN     NaN  ...
# 204                  NaN                          NaN     NaN  ...
# 205                  NaN                          NaN     NaN  ...
# 206                  NaN                          NaN     NaN  ...
#
#     Augmentations totales (AI + AG)-Toutes catégories confondues   \
# 0                                                0.058
# 1                                                  NaN
# 2                                                  NaN
# 3                                                0.025
# 4                                                  NaN
# ..                                                 ...
# 202                                                NaN
# 203                                              0.045
# 204                                              0.040
# 205                                                NaN
# 206                                                NaN
#
#     Augmentations totales (AI + AG)-Cadres/ingénieurs  \
# 0                                              0.0580
# 1                                                 NaN
# 2                                              0.0300
# 3                                              0.0250
# 4                                              0.0500
# ..                                                ...
# 202                                               NaN
# 203                                            0.0450
# 204                                            0.0400
# 205                                            0.0280
# 206                                            0.0325
#
#     Augmentations totales (AI + AG)-Professions intermédiaires (techniciens, agents de maitrise, ou autres)   \
# 0                                               0.0580
# 1                                               0.0350
# 2                                               0.0325
# 3                                               0.0250
# 4                                               0.0470
# ..                                                 ...
# 202                                             0.0350
# 203                                             0.0450
# 204                                             0.0400
# 205                                             0.0430
# 206                                             0.0450
#
#     Augmentations totales (AI + AG)-Ouviers, employés ou autres   \
# 0                                               0.0580
# 1                                               0.0350
# 2                                               0.0475
# 3                                               0.0250
# 4                                                  NaN
# ..                                                 ...
# 202                                             0.0700
# 203                                             0.0450
# 204                                             0.0400
# 205                                             0.0430
# 206                                             0.0450
#
#     Augmentations totales (AI + AG)-Talon (€) Primes -Pepa ou autres   \
# 0                                         NaN                    oui
# 1                                         NaN                     Non
# 2                                         NaN                    oui
# 3                                         NaN                    oui
# 4                                         NaN                    oui
# ..                                        ...                     ...
# 202                                       NaN                     Non
# 203                                       NaN                     Non
# 204                                       NaN                    oui
# 205                                       NaN                     Non
# 206                                       NaN                     Non
#
#     Primes Pepa ou autres-Montant en €   \
# 0                                1300.0
# 1                                   NaN
# 2                                1600.0
# 3                                2500.0
# 4                                 650.0
# ..                                  ...
# 202                                 NaN
# 203                                 NaN
# 204                               500.0
# 205                                 NaN
# 206                                 NaN
#
#     Elements exceptionnels liés à l'inflation ? Prime transport ou autre   \
# 0    prime de performance exceptionnelle + prime mé...
# 1                                                  NaN
# 2    hausse de la prise en charge des coûts du tran...
# 3                                                  NaN
# 4    prime exceptionnelle pour les ATAM de 540 (310...
# ..                                                 ...
# 202  Au regard du contexte économique général qui s...
# 203  Prime exceptionelle à hauteur de 3,5 % de la m...
# 204  - Réévaluation du forfait mensuel mobilités du...
# 205                                                NaN
# 206                                                NaN
#
#                                    Commentaires-Divers Lien
# 0                   x : Garantie de +1300e brut par an   NaN
# 1                                                  NaN   NaN
# 2    le montant de la prime est la moyenne de 1750 ...   NaN
# 3    le montant de la prime + des augmentations rep...   NaN
# 4                                                  NaN   NaN
# ..                                                 ...   ...
# 202                                                NaN   NaN
# 203                                                NaN   NaN
# 204                                                NaN   NaN
# 205                               500 euros annuel min   NaN
# 206                                                NaN   NaN
#
# [207 rows x 47 columns]

# %%
df4 = df3[['UrlLegifrance', 'Entreprise',
        # 'recherche v', 
      #   'Siret_x',
    #    'Secteur SECAFI', 
       'Secteur', 
    #    'Naf732', 'Date Texte',
    #    'Tranche Effectif(Base siren)', 'Nature', 'Titre', 'Date Maj',
    #    'Date Dépot', 'Date diffusion', 'Date fin', 
    #    'LesSyndicats', 'LesThemes',
       'Fichier', 
    #    'Unnamed: 18', 
       "Nom de l'entreprise ", 
   #     'Siret_y',
    #    'Sous secteur Secafi ', 'Secteur NAF ', 'Code NAF',
    #    "Date de l'accord du texte", 'Année d'application NAO',
    #    'Tranche Effectif (Base siren)',
       'Augmentations générales-Toutes catégories confondues ',
       'Augmentations générales-Cadres/ingénieurs',
       'Augmentations générales-Professions intermédiaires (techniciens, agents de maitrise, ou autres) ',
       'Augmentations générales-Ouviers, employés ou autres ',
       'Augmentations générales-Talon (€)',
       'Augmentations individuelles-Toutes catégories confondues ',
       'Augmentations individuelles-Cadres/ingénieurs',
       'Augmentations individuelles-Professions intermédiaires (techniciens, agents de maitrise, ou autres) ',
       'Augmentations individuelles-Ouviers, employés ou autres ',
       'Augmentations individuelles-Talon (€)',
    #    'Augmentations totales (AI + AG)-Toutes catégories confondues ',
    #    'Augmentations totales (AI + AG)-Cadres/ingénieurs',
    #    'Augmentations totales (AI + AG)-Professions intermédiaires (techniciens, agents de maitrise, ou autres) ',
    #    'Augmentations totales (AI + AG)-Ouviers, employés ou autres ',
    #    'Augmentations totales (AI + AG)-Talon (€)', 'Primes -Pepa ou autres ',
       'Primes Pepa ou autres-Montant en € ',
    #    'Elements exceptionnels liés à l'inflation ? Prime transport ou autre ',
    #    'Commentaires-Divers', 'Lien '
    ]].copy()

df4.to_excel('matching.xlsx', index=False)

# %%
df4['Num_Fichier']= df4['Fichier'].str.slice(101, 128)
df4.dropna().reset_index()
df4
# Out:
#                                          UrlLegifrance  \
# 0    https://www.legifrance.gouv.fr/acco/id/ACCOTEX...
# 1    https://www.legifrance.gouv.fr/acco/id/ACCOTEX...
# 2    https://www.legifrance.gouv.fr/acco/id/ACCOTEX...
# 3    https://www.legifrance.gouv.fr/acco/id/ACCOTEX...
# 4    https://www.legifrance.gouv.fr/acco/id/ACCOTEX...
# ..                                                 ...
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
# 205                                                NaN
# 206                                                NaN
#
#                                        Entreprise  \
# 0                                    LILLY FRANCE
# 1                                 RAMERY PROPRETE
# 2    BANQUE POPULAIRE AQUITAINE CENTRE ATLANTIQUE
# 3             GLENAT ENTREPRISES ET DEVELOPPEMENT
# 4                                 VALLOUREC TUBES
# ..                                            ...
# 202                                           NaN
# 203                                           NaN
# 204                                           NaN
# 205                                           NaN
# 206                                           NaN
#
#                             Secteur  \
# 0      Activités des sièges sociaux
# 1      Activités des sièges sociaux
# 2      Activités des sièges sociaux
# 3    Activités des sociétés holding
# 4      Activités des sièges sociaux
# ..                              ...
# 202                             NaN
# 203                             NaN
# 204                             NaN
# 205                             NaN
# 206                             NaN
#
#                                                Fichier  \
# 0    \\proapp20\PROAPP20_SQL_FILES\LAC_DONNEES\LEGI...
# 1    \\proapp20\PROAPP20_SQL_FILES\LAC_DONNEES\LEGI...
# 2    \\proapp20\PROAPP20_SQL_FILES\LAC_DONNEES\LEGI...
# 3    \\proapp20\PROAPP20_SQL_FILES\LAC_DONNEES\LEGI...
# 4    \\proapp20\PROAPP20_SQL_FILES\LAC_DONNEES\LEGI...
# ..                                                 ...
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
# 205                                                NaN
# 206                                                NaN
#
#                                   Nom de l'entreprise   \
# 0                                         LILLY FRANCE
# 1                                      RAMERY PROPRETE
# 2         BANQUE POPULAIRE AQUITAINE CENTRE ATLANTIQUE
# 3                  GLENAT ENTREPRISES ET DEVELOPPEMENT
# 4                                      VALLOUREC TUBES
# ..                                                 ...
# 202                                                EOL
# 203                                ENGIE RENOUVELABLES
# 204  AGENCE NATIONALE POUR LA FORMATION PROFESSIONN...
# 205              MAISONS & CITES SOCIETE ANONYME D'HLM
# 206                                     MACADAM FRANCE
#
#      Augmentations générales-Toutes catégories confondues   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 202                                                NaN
# 203                                                NaN
# 204                                              0.035
# 205                                                NaN
# 206                                                NaN
#
#      Augmentations générales-Cadres/ingénieurs  \
# 0                                          NaN
# 1                                          NaN
# 2                                       0.0175
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 202                                        NaN
# 203                                        NaN
# 204                                     0.0350
# 205                                     0.0200
# 206                                     0.0325
#
#      Augmentations générales-Professions intermédiaires (techniciens, agents de maitrise, ou autres)   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                0.030
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 202                                              0.035
# 203                                                NaN
# 204                                              0.035
# 205                                              0.035
# 206                                              0.045
#
#      Augmentations générales-Ouviers, employés ou autres   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                0.035
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 202                                              0.070
# 203                                                NaN
# 204                                              0.035
# 205                                              0.035
# 206                                              0.045
#
#      Augmentations générales-Talon (€)  \
# 0                                100.0
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 202                                NaN
# 203                                NaN
# 204                               75.0
# 205                               41.0
# 206                                NaN
#
#      Augmentations individuelles-Toutes catégories confondues   \
# 0                                               0.0580
# 1                                                  NaN
# 2                                               0.0125
# 3                                               0.0250
# 4                                                  NaN
# ..                                                 ...
# 202                                                NaN
# 203                                             0.0450
# 204                                             0.0050
# 205                                             0.0080
# 206                                                NaN
#
#      Augmentations individuelles-Cadres/ingénieurs  \
# 0                                           0.0580
# 1                                              NaN
# 2                                           0.0125
# 3                                           0.0250
# 4                                           0.0500
# ..                                             ...
# 202                                            NaN
# 203                                         0.0450
# 204                                         0.0050
# 205                                         0.0080
# 206                                            NaN
#
#      Augmentations individuelles-Professions intermédiaires (techniciens, agents de maitrise, ou autres)   \
# 0                                               0.0580
# 1                                               0.0350
# 2                                               0.0125
# 3                                               0.0250
# 4                                               0.0470
# ..                                                 ...
# 202                                                NaN
# 203                                             0.0450
# 204                                             0.0050
# 205                                             0.0080
# 206                                                NaN
#
#      Augmentations individuelles-Ouviers, employés ou autres   \
# 0                                               0.0580
# 1                                               0.0350
# 2                                               0.0125
# 3                                               0.0250
# 4                                                  NaN
# ..                                                 ...
# 202                                                NaN
# 203                                             0.0450
# 204                                             0.0050
# 205                                             0.0080
# 206                                                NaN
#
#      Augmentations individuelles-Talon (€)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 202                                    NaN
# 203                                    NaN
# 204                                    NaN
# 205                                    NaN
# 206                                    NaN
#
#      Primes Pepa ou autres-Montant en €                   Num_Fichier
# 0                                 1300.0  T09222038095-60984915300133
# 1                                    NaN  T59L22018355-48476299200085
# 2                                 1600.0  T03322011662-75550159001407
# 3                                 2500.0  T03822012177-34774628100034
# 4                                  650.0  T09222037846-41137352500038
# ..                                   ...                          ...
# 202                                  NaN                          NaN
# 203                                  NaN                          NaN
# 204                                500.0                          NaN
# 205                                  NaN                          NaN
# 206                                  NaN                          NaN
#
# [207 rows x 17 columns]

# %%
df5 = pd.read_excel('processed_df_V2.2.xlsx')
df_match = pd.merge(df4, df5, how='outer', left_on='Num_Fichier', right_on="Fichiers")
df_match.to_excel('checking.xlsx', index=False)

# %%
import pandas as pd
import numpy as np


df1 = pd.read_excel('BDD_NAO.xlsx', sheet_name='Echantillon NAO 2023')
df2 = pd.read_excel('BDD_NAO.xlsx', sheet_name='Saisie')
df3 = pd.merge(df1, df2, how='right', left_on=['Entreprise'], right_on=["Nom de l'entreprise "])
df4 = df3[['UrlLegifrance', 'Entreprise',
        # 'recherche v', 
      #   'Siret_x',
    #    'Secteur SECAFI', 
       'Secteur', 
    #    'Naf732', 'Date Texte',
    #    'Tranche Effectif(Base siren)', 'Nature', 'Titre', 'Date Maj',
    #    'Date Dépot', 'Date diffusion', 'Date fin', 
    #    'LesSyndicats', 'LesThemes',
       'Fichier', 
    #    'Unnamed: 18', 
       "Nom de l'entreprise ", 
   #     'Siret_y',
    #    'Sous secteur Secafi ', 'Secteur NAF ', 'Code NAF',
    #    "Date de l'accord du texte", 'Année d'application NAO',
    #    'Tranche Effectif (Base siren)',
       'Augmentations générales-Toutes catégories confondues ',
       'Augmentations générales-Cadres/ingénieurs',
       'Augmentations générales-Professions intermédiaires (techniciens, agents de maitrise, ou autres) ',
       'Augmentations générales-Ouviers, employés ou autres ',
       'Augmentations générales-Talon (€)',
       'Augmentations individuelles-Toutes catégories confondues ',
       'Augmentations individuelles-Cadres/ingénieurs',
       'Augmentations individuelles-Professions intermédiaires (techniciens, agents de maitrise, ou autres) ',
       'Augmentations individuelles-Ouviers, employés ou autres ',
       'Augmentations individuelles-Talon (€)',
    #    'Augmentations totales (AI + AG)-Toutes catégories confondues ',
    #    'Augmentations totales (AI + AG)-Cadres/ingénieurs',
    #    'Augmentations totales (AI + AG)-Professions intermédiaires (techniciens, agents de maitrise, ou autres) ',
    #    'Augmentations totales (AI + AG)-Ouviers, employés ou autres ',
    #    'Augmentations totales (AI + AG)-Talon (€)', 'Primes -Pepa ou autres ',
       'Primes Pepa ou autres-Montant en € ',
    #    'Elements exceptionnels liés à l'inflation ? Prime transport ou autre ',
    #    'Commentaires-Divers', 'Lien '
    ]].copy()

df4.to_excel('matching.xlsx', index=False)
df4['Num_Fichier']= df4['Fichier'].str.slice(101, 128)
df4.dropna().reset_index()
df5 = pd.read_excel('processed_df_V2.2.xlsx')
df_match = pd.merge(df4, df5, how='outer', left_on='Num_Fichier', right_on="Fichiers")
df_match.to_excel('checking.xlsx', index=False)
